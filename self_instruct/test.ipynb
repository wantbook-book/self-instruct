# %%
import json
prompt_file = "/pubshare/fwk/code/self-instruct/self_instruct/prompts/question_generation.json"
with open(prompt_file, 'r') as f:
    prompt_json = json.load(f)

# %%
prompt_json
# Out:
# {'system': 'Please act as a professional math teacher.\nYour goal is to create high quality math word problems to help students learn math.\nYou only need to create the new question. Please DO NOT solve it.',
#  'user': 'Come up with a series of questions:'}
